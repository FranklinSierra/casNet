# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

#mypath = "images/20211214-232746-brain/loss_output.csv"
#mypath = "images/20220112-202839-brain/loss_output.csv"
#mypath = "images/20220112-215315-brain/loss_output.csv" #1ublocks 10epochs
mypath = "images/20220119-154149-brain/loss_output.csv" #2ublocks 10epochs
d = pd.read_csv(mypath, sep=",")

plt.figure(figsize=(16,6))
plt.plot(d["ABA_reconstruction_losses"], linewidth=1, label="ABA_reconstruction_losses")
plt.plot(d["BAB_reconstruction_losses"], linewidth=1, label="BAB_reconstruction_losses")
#plt.xlim(0,250) #218
#plt.ylim(0,2)
plt.legend()
plt.show()

# %%
from PIL import Image
import numpy as np

#ruta = "data/brain/trainA/127015-frame0.png"
#ruta = "data/brain/trainB/339336-frame1.png"
ruta = "/home/gustavogarzon/data/malefemale/trainA/im4.png"
#ruta = "data/brain/testB/346290-frame0.png"

#img = Image.open(ruta).convert("L")
img = Image.open(ruta)

print(np.array(img).shape)

#img.save("geeks.png")
# Out:
# (64, 64)

# %%
ruta = "geeks.png"
#ruta = "data/brain/testB/346290-frame0.png"
img = Image.open(ruta)
print(np.array(img).shape)
# Out:
# (256, 256)

# %%
#ruta = "data/brain/testA/"
ruta = "data/brain/trainA/"

from os import listdir
for f in listdir(ruta):
    print(f)
    img = Image.open(ruta+f).convert("L")
    img.save(ruta+f)
